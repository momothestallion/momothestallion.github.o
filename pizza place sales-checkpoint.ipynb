# %%
import seaborn as sns
#sns.set()
sns.set(style="whitegrid")


import numpy as np
import pandas as pd

# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
orderdetails = pd.read_csv('order_details.csv')
orderdetails
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
order = pd.read_csv('orders.csv')
order
# Out:
#        order_id        date      time
# 0             1    1/1/2015  11:38:36
# 1             2    1/1/2015  11:57:40
# 2             3    1/1/2015  12:12:28
# 3             4    1/1/2015  12:16:31
# 4             5    1/1/2015  12:21:30
# ...         ...         ...       ...
# 21345     21346  12/31/2015  20:51:07
# 21346     21347  12/31/2015  21:14:37
# 21347     21348  12/31/2015  21:23:10
# 21348     21349  12/31/2015  22:09:54
# 21349     21350  12/31/2015  23:02:05
#
# [21350 rows x 3 columns]

# %%
pizza = pd.read_csv('pizzas.csv')
pizza
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
type_df = pd.read_csv('typepizza.csv', encoding = 'ISO-8859-1')
type_df
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# 12     pepperoni                         The Pepperoni Pizza  Classic
# 13     the_greek                             The Greek Pizza  Classic
# 14    brie_carre                        The Brie Carre Pizza  Supreme
# 15     calabrese                         The Calabrese Pizza  Supreme
# 16     ital_supr                   The Italian Supreme Pizza  Supreme
# 17  peppr_salami                     The Pepper Salami Pizza  Supreme
# 18    prsc_argla            The Prosciutto and Arugula Pizza  Supreme
# 19      sicilian                          The Sicilian Pizza  Supreme
# 20   soppressata                       The Soppressata Pizza  Supreme
# 21    spicy_ital                     The Spicy Italian Pizza  Supreme
# 22  spinach_supr                   The Spinach Supreme Pizza  Supreme
# 23   five_cheese                       The Five Cheese Pizza   Veggie
# 24   four_cheese                       The Four Cheese Pizza   Veggie
# 25  green_garden                      The Green Garden Pizza   Veggie
# 26   ital_veggie                The Italian Vegetables Pizza   Veggie
# 27  mediterraneo                     The Mediterranean Pizza   Veggie
# 28      mexicana                          The Mexicana Pizza   Veggie
# 29    spin_pesto                     The Spinach Pesto Pizza   Veggie
# 30   spinach_fet                  The Spinach and Feta Pizza   Veggie
# 31    veggie_veg           The Vegetables + Vegetables Pizza   Veggie
#
#                                           ingredients
# 0   Barbecued Chicken, Red Peppers, Green Peppers,...
# 1   Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 2   Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 3   Chicken, Tomatoes, Red Peppers, Spinach, Garli...
# 4   Chicken, Tomatoes, Red Peppers, Red Onions, Ja...
# 5   Chicken, Pineapple, Tomatoes, Red Peppers, Tha...
# 6   Bacon, Pepperoni, Italian Sausage, Chorizo Sau...
# 7   Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 8            Sliced Ham, Pineapple, Mozzarella Cheese
# 9   Capocollo, Red Peppers, Tomatoes, Goat Cheese,...
# 10  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 11                Pepperoni, Mushrooms, Green Peppers
# 12                       Mozzarella Cheese, Pepperoni
# 13  Kalamata Olives, Feta Cheese, Tomatoes, Garlic...
# 14  Brie Carre Cheese, Prosciutto, Caramelized Oni...
# 15  Nduja Salami, Pancetta, Tomatoes, Red Onions,...
# 16  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 17  Genoa Salami, Capocollo, Pepperoni, Tomatoes, ...
# 18  Prosciutto di San Daniele, Arugula, Mozzarella...
# 19  Coarse Sicilian Salami, Tomatoes, Green Olives...
# 20  Soppressata Salami, Fontina Cheese, Mozzarella...
# 21  Capocollo, Tomatoes, Goat Cheese, Artichokes, ...
# 22  Spinach, Red Onions, Pepperoni, Tomatoes, Arti...
# 23  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 24  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 25  Spinach, Mushrooms, Tomatoes, Green Olives, Fe...
# 26  Eggplant, Artichokes, Tomatoes, Zucchini, Red ...
# 27  Spinach, Artichokes, Kalamata Olives, Sun-drie...
# 28  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 29  Spinach, Artichokes, Tomatoes, Sun-dried Tomat...
# 30  Spinach, Mushrooms, Red Onions, Feta Cheese, G...
# 31  Mushrooms, Tomatoes, Red Peppers, Green Pepper...

# %%
pizza_df= type_df.merge(pizza, how='left', on = 'pizza_type_id')
pizza_df
# Out:
#    pizza_type_id                               name category  \
# 0        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 1        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 2        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 3       cali_ckn       The California Chicken Pizza  Chicken
# 4       cali_ckn       The California Chicken Pizza  Chicken
# ..           ...                                ...      ...
# 91   spinach_fet         The Spinach and Feta Pizza   Veggie
# 92   spinach_fet         The Spinach and Feta Pizza   Veggie
# 93    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 94    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 95    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
#
#                                           ingredients       pizza_id size  \
# 0   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_s    S
# 1   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_m    M
# 2   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_l    L
# 3   Chicken, Artichoke, Spinach, Garlic, Jalapeno ...     cali_ckn_s    S
# 4   Chicken, Artichoke, Spinach, Garlic, Jalapeno ...     cali_ckn_m    M
# ..                                                ...            ...  ...
# 91  Spinach, Mushrooms, Red Onions, Feta Cheese, G...  spinach_fet_m    M
# 92  Spinach, Mushrooms, Red Onions, Feta Cheese, G...  spinach_fet_l    L
# 93  Mushrooms, Tomatoes, Red Peppers, Green Pepper...   veggie_veg_s    S
# 94  Mushrooms, Tomatoes, Red Peppers, Green Pepper...   veggie_veg_m    M
# 95  Mushrooms, Tomatoes, Red Peppers, Green Pepper...   veggie_veg_l    L
#
#     price
# 0   12.75
# 1   16.75
# 2   20.75
# 3   12.75
# 4   16.75
# ..    ...
# 91  16.00
# 92  20.25
# 93  12.00
# 94  16.00
# 95  20.25
#
# [96 rows x 7 columns]

# %%
order_df= orderdetails.merge(order, how='left', on = 'order_id')
order_df
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#            time
# 0      11:38:36
# 1      11:57:40
# 2      11:57:40
# 3      11:57:40
# 4      11:57:40
# ...         ...
# 48615  21:23:10
# 48616  21:23:10
# 48617  21:23:10
# 48618  22:09:54
# 48619  23:02:05
#
# [48620 rows x 6 columns]

# %%
pizzass_df= pizza_df.merge(order_df, how='left', on = 'pizza_id')
pizzass_df
# Out:
#       pizza_type_id                               name category  \
# 0           bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 1           bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 2           bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 3           bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 4           bbq_ckn         The Barbecue Chicken Pizza  Chicken
# ...             ...                                ...      ...
# 48620    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 48621    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 48622    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 48623    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 48624    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
#
#                                              ingredients      pizza_id size  \
# 0      Barbecued Chicken, Red Peppers, Green Peppers,...     bbq_ckn_s    S
# 1      Barbecued Chicken, Red Peppers, Green Peppers,...     bbq_ckn_s    S
# 2      Barbecued Chicken, Red Peppers, Green Peppers,...     bbq_ckn_s    S
# 3      Barbecued Chicken, Red Peppers, Green Peppers,...     bbq_ckn_s    S
# 4      Barbecued Chicken, Red Peppers, Green Peppers,...     bbq_ckn_s    S
# ...                                                  ...           ...  ...
# 48620  Mushrooms, Tomatoes, Red Peppers, Green Pepper...  veggie_veg_l    L
# 48621  Mushrooms, Tomatoes, Red Peppers, Green Pepper...  veggie_veg_l    L
# 48622  Mushrooms, Tomatoes, Red Peppers, Green Pepper...  veggie_veg_l    L
# 48623  Mushrooms, Tomatoes, Red Peppers, Green Pepper...  veggie_veg_l    L
# 48624  Mushrooms, Tomatoes, Red Peppers, Green Pepper...  veggie_veg_l    L
#
#        price  order_details_id  order_id  quantity        date      time
# 0      12.75              11.0       6.0       1.0    1/1/2015  12:29:36
# 1      12.75             239.0     102.0       1.0    1/2/2015  17:54:04
# 2      12.75             294.0     124.0       1.0    1/2/2015  20:12:34
# 3      12.75             458.0     194.0       1.0    1/3/2015  21:21:24
# 4      12.75             489.0     208.0       1.0    1/4/2015  12:12:05
# ...      ...               ...       ...       ...         ...       ...
# 48620  20.25           48341.0   21230.0       1.0  12/29/2015  14:43:26
# 48621  20.25           48452.0   21278.0       1.0  12/31/2015  11:22:31
# 48622  20.25           48523.0   21305.0       1.0  12/31/2015  16:31:16
# 48623  20.25           48548.0   21317.0       1.0  12/31/2015  18:01:42
# 48624  20.25           48588.0   21336.0       1.0  12/31/2015  19:19:26
#
# [48625 rows x 12 columns]

# %%
pizzass_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48625 entries, 0 to 48624
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pizza_type_id     48625 non-null  object
#  1   name              48625 non-null  object
#  2   category          48625 non-null  object
#  3   ingredients       48625 non-null  object
#  4   pizza_id          48625 non-null  object
#  5   size              48625 non-null  object
#  6   price             48625 non-null  float64
#  7   order_details_id  48620 non-null  float64
#  8   order_id          48620 non-null  float64
#  9   quantity          48620 non-null  float64
#  10  date              48620 non-null  object
#  11  time              48620 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 4.8+ MB

# %%
#changing to datetime datatype
pizzass_df['date']=pd.to_datetime(pizzass_df['date'])

# %%
pizzass_df['time']=pd.to_datetime(pizzass_df['time'])

# %%
#how many cutomers do we have each day, are there any peak hours?
pp= pizzass_df.groupby(['date','time'])['order_id'].count().sort_values(ascending=False)
pp
# Out:
# date        time
# 2015-06-30  2022-11-19 13:31:27    21
# 2015-11-18  2022-11-19 12:25:12    21
# 2015-12-27  2022-11-19 15:29:39    15
# 2015-12-18  2022-11-19 13:24:39    15
# 2015-11-08  2022-11-19 11:50:27    15
#                                    ..
# 2015-07-04  2022-11-19 16:39:54     1
#             2022-11-19 16:28:56     1
#             2022-11-19 16:18:12     1
#             2022-11-19 16:17:15     1
# 2015-01-01  2022-11-19 11:38:36     1
# Name: order_id, Length: 21350, dtype: int64

# %%
pizzass_df.groupby(['date','time'])['order_id'].count().sort_values(ascending=False).plot(kind='line', figsize=(20,10))

# %%
#how much money did we make this year? can we identify any seasonality
py = pizzass_df.groupby('order_id')['price'].sum()
py
# Out:
# order_id
# 1.0        13.25
# 2.0        92.00
# 3.0        37.25
# 4.0        16.50
# 5.0        16.50
#            ...
# 21346.0    62.25
# 21347.0    66.50
# 21348.0    46.70
# 21349.0    20.25
# 21350.0    12.75
# Name: price, Length: 21350, dtype: float64

# %%
#how much money did we make this year? can we identify any seasonality
pizzass_df.price.sum()
# Out:
# 802020.95

# %%
#how much money did we make this year? can we identify any seasonality
pizzass_df.groupby("order_id")["date"].value_counts()
# Out:
# order_id  date
# 1.0       2015-01-01    1
# 2.0       2015-01-01    5
# 3.0       2015-01-01    2
# 4.0       2015-01-01    1
# 5.0       2015-01-01    1
#                        ..
# 21346.0   2015-12-31    4
# 21347.0   2015-12-31    4
# 21348.0   2015-12-31    3
# 21349.0   2015-12-31    1
# 21350.0   2015-12-31    1
# Name: date, Length: 21350, dtype: int64

# %%
#how many pizza are in an order? do we have any best seller?
pizzass_df.groupby("order_id")["pizza_type_id"].value_counts()
# Out:
# order_id  pizza_type_id
# 1.0       hawaiian         1
# 2.0       classic_dlx      1
#           five_cheese      1
#           ital_supr        1
#           mexicana         1
#                           ..
# 21348.0   ckn_alfredo      1
#           four_cheese      1
#           napolitana       1
# 21349.0   mexicana         1
# 21350.0   bbq_ckn          1
# Name: pizza_type_id, Length: 47316, dtype: int64

# %%
pizzass_df.groupby("pizza_type_id")["order_details_id"].value_counts()
# Out:
# pizza_type_id  order_details_id
# bbq_ckn        11.0                1
#                26.0                1
#                43.0                1
#                63.0                1
#                71.0                1
#                                   ..
# veggie_veg     48523.0             1
#                48548.0             1
#                48553.0             1
#                48571.0             1
#                48588.0             1
# Name: order_details_id, Length: 48620, dtype: int64
